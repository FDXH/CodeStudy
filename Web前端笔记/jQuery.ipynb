# %% [markdown]
# # jQuery
# - jQuery是一个免费、开源的JavaScript库，也是目前使用最广泛的JavaScript函数库。
# - jQuery极大地方便你完成web前端的相关操作，例如节点操作，元素操作，事件绑定，ajax操作且解决了绝大多数的兼容性问题
# - jQuery的版本分为1.x系列和2.x、3.x系列，1.x系列兼容低版本的浏览器，2.x、3.x系列放弃支持低版本的浏览器，目前使用最多的是1.x系列
# - http://jquery.com/官方网站
# - jQuery是一个函数库，一个js文件，页面用script标签引入这个js文件就可以使用。
# - <script type="text/javascript" src="js/jquery-1.8.3.min.js"></script>
#
# ## jQuery选择器
# ### jQuery用法思想
# - 选择某个网页元素，然后对它来进行某种操作
# ### jQuery选择器
# - jQuery选择器可以快速地选择元素，选择规则和css样式相同
# - 基础选择器
# - 过滤获取
# - 父子关系获取
#
# ## jQuery操作
# ### css操作行内样式
# - 特别注意 ：选择器获取的多个元素，获取信息获取的是第一个
#
# ### 类名class操作
# - 操作样式类名
#
# ### 文本操作
# - 取出或设置html内容
# - text取出或设置text内容
#
# ### 属性操作
# - attr（）取出或设置某个属性的值
# - removeattr（）删除属性
#
# ### 相关尺寸
# - 获取元素相对于文档的偏移量:
#     - var pos = $('#small').offset();
#     - //console.log(pos.left);//consloe.log(pos.top);
# - 获取当前元素相对于父级元素的偏移量
#     - var l = $('#small').position().left;
#     - var t = $('#small').position().top;
# - 获取文档滚动距离
#     - var st = $(document).scrollTop();
#     - var sl = $(document).scrollLeft();
# - 获取或设置元素的宽度和高度
#     - var w = $('#big').width();
#     - var h = $('#big').height();
# - 获取可视区域的宽度和高度
#     - var cw = $(window).width();
#     - var ch = $(window).heighr();
# - 获取文档的高度和宽度
#     - vae vrw =$(document).width();
#     - vae vrh =$(document).height();

# %% [markdown]
# ### 事件绑定
# - 事件绑定
# - 方法绑定
# - 动态绑定
#
# ### 常用的鼠标事件
# - 鼠标单击事件 click
# - 鼠标双击事件 dbclick
# - 鼠标移出事件 mouseout
# - 鼠标按下事件 mousedown
# - 鼠标抬起事件 mouseup
# - 鼠标移动事件 mousemove
#
# ### 事件冒泡和默认行为
# #### 事件冒泡
# - 当触发一个元素的事件时，会自动触发该元素的父级和先辈级的同类型事件，造成事件并发，导致页面混乱，我们称为事件冒泡，此时我们可以再元素的事件处理函数中，返回一个false来进行阻止，注意仅在jquery中使用
#
# #### 默认行为
# - 在页面中有些元素是具备默认行为的，例如a链接的单击，表单的提交等
# - 但是在绑定事件后，它首先会执行事件，再去执行默认行为，而有时我们只想让其触发事件，但不执行默认行为时，我们可以再该元素的事件中返回一个false来进行阻止默认行为
#
# ### 获得当前鼠标的位置和按键
# - 我们有鼠标和键盘按键的事件，在触发事件时如果我们想要获取鼠标的位置或键盘信息时，首先需要在当前的事件中传递一个事件对象e
#
# ### jQuery节点操作
# - 创建节点
# - 插入节点
# - 删除节点
# - 克隆节点
