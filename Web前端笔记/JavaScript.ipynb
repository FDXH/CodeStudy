# %% [markdown]
# # JavaScript
#
# ## 目标
# - 学习前端脚本语言JavaScript的基本概念、页面引入方式、获取页面元素及操作元素属性的技巧，学习函数的基本第一方法和使用方法。
#
# ## 前端三大块
# - html：负责页面结构
# - css：页面的表现形式
# - JavaScript：页面的动态效果和一些简单的特效
#
# ## 什么是JavaScript
# - JavaScript是运行在浏览器端的脚本语言，JavaScript主要解决的是前端与用户交互的问题，包括使用交互与数据交互，JavaScript是浏览器解释执行的
# - 1.JavaScript是一种客户端脚本语言（脚本语言是一种轻量级的编程语言）
# - 2.JavaScript通常被直接嵌入html页面
# - 3.是一种解释性语言（代码执行不进行预编译）
#
# ## 特点
# - 弱类型
# - 基于对象（面对对象需要具有继承、封装、多态的特征）
# - 安全
# - 兼容性
#
# ## JavaScript嵌入页面的方式
# - 页面script标签引入
# - 外部引入
# - 行间事件（主要用于事件）
#
# ## JavaScript变量
# - JavaScript是一种弱类型语言，JavaScript的变量类型由它的值来决定
# - 定义变量需要用关键字‘var’
# - 不适用var关键字定义全局变量在严格模式下将会执行错误“use strict”
#
# ## JavaScript基本数据类型
# - boolean
# - number：整数、浮点数
# - string：采用“”‘’
# - object
# - function
# - undefined
#
# ## JavaScript数据类型转换
# - 使用Number（）、parseInt（）和parseFloat（）做类型转换
# - isNaA() 检测一个数据是否是一个数
#
# ## JavaScript运算符
# - 算数运算符
# - 字符串链接
# - 赋值运算
# - 比较运算符
# - 逻辑运算符
# - 位运算
#
# ## JavaScript元素获取与操作
# - 可以使用内置对象document上的getElementById方法来获取页面上设置了id属性的元素，获取到的是一个html对象，然后将它赋值给一个变量，比如

# %% [markdown]
# <script type = "text/javascript">
#     var oDiv = document.getElementById('div1')
# </script>
# ....
# <div id="div1">这是一个div元素</div>

# %% [markdown]
# - 上面的语句，如果把JavaScript写在元素的上面，就会出错，因为页面上从上往下加载执行的，JavaScript去页面上获取元素div1的时候，元素还没有加载，解决办法有两种
#     - 第一种方法，将JavaScript放到页面最下面
#     - 第二种方法：将JavaScript语句放到window.onload触发的函数里面，获取元素的语句会在页面加载完后才执行，就不会出错了

# %% [markdown]
# ## 样式操作
# - 标签对象style.css属性名="值"   改变标签对象的样式
#     - 实例：id.style.color = "red"
#     - 注意：属性名相当于变量名，所以css属性名中含有双排词的(font-size)的'-'号要去掉，将后面的首字母大写 fontSize
#
# ## 文本操作
# - 标签对象innerHtml = "内容"
# - 文本对象innerText = ""
#
# ## 表单中值的操作
# - 标签对象 value //获取标签对象的value值
# - 标签对象 value = "值" //设置标签对象的value值
#
# ## js定时器
# - 通过使用JavaScript，我们有能力做到在一个设定的时间间隔之后来执行代码，而不是在函数被调用后立即执行，我们称之为计时事件
#
# ### 定时器在JavaScript中的作用
# - 制作动画
# - 异步操作
#
# ### 定时器类型与语法
# - setInterval：间隔指定的毫秒数不停地执行指定的代码
# - setTimeout：暂停指定的毫秒数后执行指定的代码
# - setInterval()和setTimeout()是windo对象的两个方法
#
# ## js函数
# - 第一种使用function语句定义函数
# - 第二种在表达式中定义函数
#
# ### arguments
# - 在函数代码中，使用特殊对象arguments，开发者无需明确指出参数名，就能访问它们。例如，在函数sayHi()中，第一个参数是message，用arguments[0]也可以访问这个值，即第一个参数的值（第一个参数位于位置0，第二个参数位于位置1，以此类推）
#
# ### 关于变量和参数问题
# - 函数外面定义的变量是全局变量，函数内可以直接使用。
# - 在函数内部没有使用car定义的变量则为全局变量
# - 在函数内使用var关键字定义的变量是局部变量，即出了函数外边无法获取
# - js函数定义的参数没有默认值。
#
# ## js对象
# - 1.使用原始的方式创建内置对象
#     - var myproject = new Object（）；
#     - myproject.name = "";
#     - myproject.age = 20;
# - 2.直接创建自定义对象
#     - var 对象名 = {属性名1：属性值,属性名2：属性值，......}
# - 3.使用自定义构造函数创建对象
#     - function pen(name,color,price){this.name = name;this.colo = color;this.price=price}
#
# ### this关键字
# - this这个单词就是 这个 的意思
# - 在对象的方法中使用，代表着当前这个对象
# - 意味着当对象使用这个方法时，方法中的this就代表着这个对象
# ### 遍历对象
# - for(var i in window){ decument.write(i+"----"+window[i])}
# - 这种语句可以遍历对象中的所有属性或数组中的所有元素。
# ### 关于类型
# - 测试类型：
#     - 1.typeof()
#     - 2.对象.constructor
#
# ## js数组
# - 数据就是一组数据的集合，JavaScript中，数组里面的数据可以是不同类型的。
# - 定义数组的方法：
#     - var alist = new Arrat(1,2,3);
#     - var alist2 = new [1,2,3,'asd'];
# - 操作数组中数据的方法：
#     - 1.获取数组的长度：aList.length;
#     - 2.用下标操作数组的某个数组：aList[0];
#     - 3.push()和pop()从数组最后增加成员或删除成员
#     - 4.unshift()和shift()从数组前面增加成员或删除成员
#     - 5.sploce()在数组中增加或删除成员
#
# - 多维数组
#     - 即数组的成员也是数组
#
# ## js数学对象math
# - 四舍五入：Math.round();
# - 获取最大最小值：Math.max();Math.min();
# - 获取绝对值:Math.abs();
# - 幂运算：Math.pow();
# - 进一取整：Math..floor();
# - 退一取整：Math.ceil();
# - 开方运算：Math.sqrt();
#
# ## random返回0~1之间的随机数
# - Math.random获取一个随机数，返回0~1之间的随机小数，有可能到0，但是不会取到1
# - 自己封装一个函数取区间内的随机数：rand();

# %%
function rand(m,n){
    return Math.floor(Math.random()*(n-m+1))+(n-m)
}
var res = rand(20,30)
